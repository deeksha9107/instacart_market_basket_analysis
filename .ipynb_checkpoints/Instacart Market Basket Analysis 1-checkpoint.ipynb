# %%
# Instacart Market Basket Analysis 1 - Initial Analysis

# %%
# 1. Data Cleaning, Description and Analysis

# %%
#1: Library Imports
# !pip install kaggle
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn

# %%
#replace with your username and key
# %env KAGGLE_USERNAME=
# %env KAGGLE_KEY=
# Out:
# env: KAGGLE_USERNAME=
# env: KAGGLE_KEY=

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

matplotlib.rcParams['figure.dpi'] = 120 #resolution
matplotlib.rcParams['figure.figsize'] = (8,6) #figure size
sns.set_style('darkgrid')
# matplotlib and seaborn for plotting
matplotlib.rcParams['figure.dpi'] = 120 #resolution
matplotlib.rcParams['figure.figsize'] = (8,6) #figure size
color = sns.color_palette()
# pd.set_option('max_columns', 150)

# %%
#2. Fetch the data

# %%
# !kaggle competitions download -c instacart-market-basket-analysis -p ../instacart_data_files/
# Out:
# ...
# 100%|███████████████████████████████████████▉| 196M/196M [00:13<00:00, 17.6MB/s]
# 100%|████████████████████████████████████████| 196M/196M [00:13<00:00, 15.1MB/s]

# %%
# !unzip -o ../instacart_data_files/instacart-market-basket-analysis.zip -d ../instacart_data_files/
# Out:
# Archive:  ../instacart_data_files/instacart-market-basket-analysis.zip
#   inflating: ../instacart_data_files/aisles.csv.zip
#   inflating: ../instacart_data_files/departments.csv.zip
#   inflating: ../instacart_data_files/order_products__prior.csv.zip
#   inflating: ../instacart_data_files/order_products__train.csv.zip
#   inflating: ../instacart_data_files/orders.csv.zip
#   inflating: ../instacart_data_files/products.csv.zip
#   inflating: ../instacart_data_files/sample_submission.csv.zip

# %%
import os
root = '../instacart_data_files/'
dirs = os.listdir(root)
print("dirs: ", dirs)
# Out:
# dirs:  ['order_products__prior.csv.zip', 'order_products__train.csv.zip', 'aisles.csv.zip', 'orders.csv.zip', 'departments.csv.zip', 'products.csv.zip', 'sample_submission.csv.zip', 'instacart-market-basket-analysis.zip']

# %%
for filename in os.listdir(root):
  if not filename.endswith(".zip"):
    continue
  os.system("unzip -o {} -d {}".format(os.path.join(root, filename), root))
# Out:
# Archive:  ../instacart_data_files/order_products__prior.csv.zip
#   inflating: ../instacart_data_files/order_products__prior.csv
#    creating: ../instacart_data_files/__MACOSX/
#   inflating: ../instacart_data_files/__MACOSX/._order_products__prior.csv
# Archive:  ../instacart_data_files/order_products__train.csv.zip
#   inflating: ../instacart_data_files/order_products__train.csv
#   inflating: ../instacart_data_files/__MACOSX/._order_products__train.csv
# Archive:  ../instacart_data_files/aisles.csv.zip
#   inflating: ../instacart_data_files/aisles.csv
#   inflating: ../instacart_data_files/__MACOSX/._aisles.csv
# Archive:  ../instacart_data_files/orders.csv.zip
#   inflating: ../instacart_data_files/orders.csv
#   inflating: ../instacart_data_files/__MACOSX/._orders.csv
# Archive:  ../instacart_data_files/departments.csv.zip
#   inflating: ../instacart_data_files/departments.csv
#   inflating: ../instacart_data_files/__MACOSX/._departments.csv
# ...

# %%
aisles = pd.read_csv(root + 'aisles.csv')
departments = pd.read_csv(root + 'departments.csv')
orders = pd.read_csv(root + 'orders.csv')
order_products_prior = pd.read_csv(root + 'order_products__prior.csv')
order_products_train = pd.read_csv(root + 'order_products__train.csv')
products = pd.read_csv(root + 'products.csv')

# %%
##1. Data Cleaning

# %%
print("orders has null values")
print("aisles null values? ", aisles.isnull().values.any())
print("departments null values? ", departments.isnull().values.any())
print("orders null values? ", orders.isnull().values.any())
print("order_products_prior null values? ", order_products_prior.isnull().values.any())
print("order_products_train null values? ", order_products_train.isnull().values.any())
print("products null values? ", products.isnull().values.any())
# Out:
# orders has null values
# aisles null values?  False
# departments null values?  False
# orders null values?  True
# order_products_prior null values?  False
# order_products_train null values?  False
# products null values?  False

# %%
missing_values_count = orders.isnull().sum()
print(missing_values_count)
print("For every user’s 1st order, the days_since_prior_order is Nan, which makes sense. We can impute 0 here.")
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64
# For every user’s 1st order, the days_since_prior_order is Nan, which makes sense. We can impute 0 here.

# %%
print("Order shape: ", orders.shape)
orders.loc[orders['order_number'] == 1] = orders.loc[orders['order_number'] == 1].fillna(0)
print("Order shape: ", orders.shape)
print("orders null values? ", orders.isnull().values.any())
# Out:
# Order shape:  (3421083, 7)
# Order shape:  (3421083, 7)
# orders null values?  False

# %%
#2. Data Description
# Aisles:

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
print("Number of unique aisles: ", len(aisles.aisle_id.unique()))
# Out:
# Number of unique aisles:  134

# %%
# Departments:

# %%
departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
print("Number of unique departments: ", len(departments.department_id.unique()))
# Out:
# Number of unique departments:  21

# %%
print("Unique Department Names: ", departments.department.unique())
# Out:
# Unique Department Names:  ['frozen' 'other' 'bakery' 'produce' 'alcohol' 'international' 'beverages'
#  'pets' 'dry goods pasta' 'bulk' 'personal care' 'meat seafood' 'pantry'
#  'breakfast' 'canned goods' 'dairy eggs' 'household' 'babies' 'snacks'
#  'deli' 'missing']

# %%
#Orders:

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day
# 0   2539329        1    prior             1          2                  8  \
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     0.0
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
print("Number of orders made: {v1} by number of users: {v2} ".format(v1 = len(orders.order_id.unique()), v2 = len(orders.user_id.unique())))
# Out:
# Number of orders made: 3421083 by number of users: 206209

# %%
print("The total orders per customer ranges from 0 to 100.")
orders.order_number.describe().apply(lambda x: format(x, '.2f'))
# Out:
# The total orders per customer ranges from 0 to 100.
# count    3421083.00
# mean          17.15
# std           17.73
# min            1.00
# 25%            5.00
# 50%           11.00
# 75%           23.00
# max          100.00
# Name: order_number, dtype: object

# %%
order_number = orders.groupby('user_id')['order_number'].max()
order_number = order_number.value_counts()
order_number
# Out:
# order_number
# 4     23986
# 5     19590
# 6     16165
# 7     13850
# 8     11700
#       ...
# 94       57
# 91       56
# 97       54
# 98       50
# 99       47
# Name: count, Length: 97, dtype: int64

# %%
print("The total orders per customer ranges from 0 to 100.")
fig, ax = plt.subplots(figsize=(15,8))
ax = sns.barplot(x = order_number.index, y = order_number.values, color = color[3])
ax.set_xlabel('Orders per customer')
ax.set_ylabel('Count')
ax.xaxis.set_tick_params(rotation=90, labelsize=10)
ax.set_title('Frequency of Total Orders by Customers')
fig.savefig('Frequency of Total Orders by Customers.png')
# Out:
# The total orders per customer ranges from 0 to 100.

# %%
print("There are three sets of orders: Prior, Train and Test. This file tells to which set (prior, train, test) an order belongs")
orders.eval_set.value_counts()
# Out:
# There are three sets of orders: Prior, Train and Test. This file tells to which set (prior, train, test) an order belongs
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (8,4))
ax = sns.kdeplot(orders.order_number[orders.eval_set == 'prior'], label = "Prior set", lw = 1)
ax = sns.kdeplot(orders.order_number[orders.eval_set == 'train'], label = "Train set", lw = 1)
ax = sns.kdeplot(orders.order_number[orders.eval_set == 'test'], label = "Test set", lw = 1)
ax.set_xlabel('Order Number')
ax.set_ylabel('Count')
ax.tick_params(axis = 'both', labelsize = 10)
ax.set_title('Distribution of Orders in Various Sets')
fig.savefig('Distribution of Orders in Various Sets.png')
plt.show()

# %%
orders.order_hour_of_day.describe().apply(lambda x: format(x, '.2f'))
# Out:
# count    3421083.00
# mean          13.45
# std            4.23
# min            0.00
# 25%           10.00
# 50%           13.00
# 75%           16.00
# max           23.00
# Name: order_hour_of_day, dtype: object

# %%
print("Which days were the most orders made?")
print("Saturdays and Sundays being weekends saw the most orders made. Based on the heatmap between 'Day of Week' and 'Hour of Day,' we can say that Saturday afternoons and Sunday mornings are prime time for orders.")
# Out:
# Which days were the most orders made?
# Saturdays and Sundays being weekends saw the most orders made. Based on the heatmap between 'Day of Week' and 'Hour of Day,' we can say that Saturday afternoons and Sunday mornings are prime time for orders.

# %%
orders_per_day = orders.groupby('order_dow').count()['order_id']

weekday_map = {0: 'Saturday', 1: 'Sunday', 2: 'Monday', 3: 'Tuesday', 4: 'Wednesday', 5: 'Thursday', 6: 'Friday'}

orders_per_day.index = orders_per_day.index.map(weekday_map)

# create a bar plot of the orders per day
plt.bar(orders_per_day.index, orders_per_day.values)

# add labels and title
plt.xlabel('Day of Week')
plt.ylabel('Total Orders')
plt.title('Total Orders per Day of Week')

# show the plot
plt.show()

# %%
print("2.What was the most prominent time for ordering?")
print("Majority of the orders are made during the day time.")
# Out:
# 2.What was the most prominent time for ordering?
# Majority of the orders are made during the day time.

# %%
print("Majority of the orders are made during the day time.")
orders_per_hour = orders.groupby('order_hour_of_day').count()['order_id']

# create a line plot of the orders per hour
plt.plot(orders_per_hour.index, orders_per_hour.values)

# add labels and title
plt.xlabel('Hour of Day')
plt.ylabel('Total Orders')
plt.title('Total Orders per Hour of Day')

# show the plot
plt.show()
# Out:
# Majority of the orders are made during the day time.

# %%
print("3.Gap days between reorders from customers?")
print("Customers order once in a week which is supported by peaks at 7, 14, 21 and 30 in 'Orders VS Days since prior order' graph.")
# Out:
# 3.Gap days between reorders from customers?
# Customers order once in a week which is supported by peaks at 7, 14, 21 and 30 in 'Orders VS Days since prior order' graph.

# %%
print("Customers order once in a week which is supported by peaks at 7, 14, 21 and 30 in 'Orders VS Days since prior order' graph.")

orders_vs_days = orders[['days_since_prior_order', 'order_number']].dropna()
orders_vs_days['days_since_prior_order'] = orders_vs_days['days_since_prior_order'].astype('float64')
orders_vs_days.head()
# Out:
# Customers order once in a week which is supported by peaks at 7, 14, 21 and 30 in 'Orders VS Days since prior order' graph.
#    days_since_prior_order  order_number
# 0                     0.0             1
# 1                    15.0             2
# 2                    21.0             3
# 3                    29.0             4
# 4                    28.0             5

# %%
# # group the orders by days since the prior order and count the number of orders in each group
orders_by_days = orders_vs_days.groupby('days_since_prior_order').count()['order_number']
orders_by_days.head()
# Out:
# days_since_prior_order
# 0.0    273964
# 1.0    145247
# 2.0    193206
# 3.0    217005
# 4.0    221696
# Name: order_number, dtype: int64

# %%
# create a bar plot of the orders vs days
plt.bar(orders_by_days.index, orders_by_days.values)
plt.xticks(orders_by_days.index)
# add labels and title
plt.xlabel('Days Since Prior Order')
plt.ylabel('Total Orders')
plt.title('Orders vs Days Since Prior Order')
# show the plot
plt.show()

# %%
temp_df = orders.groupby(["order_dow", "order_hour_of_day"])["order_number"].aggregate("count").reset_index()
temp_df = temp_df.pivot(index='order_dow', columns='order_hour_of_day', values='order_number')
temp_df.head()
# Out:
# order_hour_of_day    0     1     2    3    4     5     6      7      8
# order_dow
# 0                  3936  2398  1409  963  813  1168  3329  12410  28108  \
# 1                  3674  1830  1105  748  809  1607  5370  16571  34116
# 2                  3059  1572   943  719  744  1399  4758  13245  24635
# 3                  2952  1495   953  654  719  1355  4562  12396  22553
# 4                  2642  1512   899  686  730  1330  4401  12493  21814
#
# order_hour_of_day     9   ...     14     15     16     17     18     19
# order_dow                 ...
# 0                  40798  ...  54552  53954  49463  39753  29572  22654  \
# 1                  51908  ...  46764  46403  44761  36792  28977  22145
# 2                  36314  ...  37173  37469  37541  32151  26470  20084
# 3                  32312  ...  34773  35990  35273  30368  25001  19249
# 4                  31409  ...  33625  34222  34093  29378  24425  19350
#
# order_hour_of_day     20     21     22    23
# order_dow
# ...

# %%
print("Based on the heatmap between 'Day of Week' and 'Hour of Day,' we can say that Saturday afternoons and Sunday mornings are prime time for orders.")
ax = plt.subplots(figsize=(7,3))
ax = sns.heatmap(temp_df, cmap="YlGnBu", linewidths=.5)
ax.set_title("Frequency of Day of week Vs Hour of day", size = 12)
ax.set_xlabel("Hour of Day", size = 10)
ax.set_ylabel("Day of Week", size = 10)
ax.tick_params(axis = 'both', labelsize = 8)
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=10)
fig = ax.get_figure()
fig.savefig("Frequency of Day of week Vs Hour of day.png")
plt.show()
# Out:
# Based on the heatmap between 'Day of Week' and 'Hour of Day,' we can say that Saturday afternoons and Sunday mornings are prime time for orders.

# %%
#Order Products Prior:

# %%
order_products_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
print("Total: {v1} orders were made where total {v2} products were ordered.".format(v1 = len(order_products_prior.order_id.unique()), v2 = len(order_products_prior.product_id.unique())))
# Out:
# Total: 3214874 orders were made where total 49677 products were ordered.

# %%
add_to_cart_order_prior = order_products_prior.groupby('order_id')['add_to_cart_order'].count()
add_to_cart_order_prior.head()
# Out:
# order_id
# 2     9
# 3     8
# 4    13
# 5    26
# 6     3
# Name: add_to_cart_order, dtype: int64

# %%
add_to_cart_order_prior = add_to_cart_order_prior.value_counts()
add_to_cart_order_prior.head()
# Out:
# add_to_cart_order
# 5    228330
# 6    227675
# 4    222081
# 7    220006
# 3    207027
# Name: count, dtype: int64

# %%
add_to_cart_order_prior.index.max()
# Out:
# 145

# %%
print("Most of the people buy 1-15 items in an order and there were a maximum of 145 items in an order.")
fig, ax = plt.subplots(figsize = (15,8))
ax = sns.barplot(x = add_to_cart_order_prior.index, y = add_to_cart_order_prior.values, color = color[3])
ax.set_xlabel('Items in cart')
ax.set_ylabel('Count')
ax.xaxis.set_tick_params(rotation=90, labelsize = 9)
ax.set_title('Frequency of Items in Cart in Prior set', size = 15)
fig.savefig('Frequency of Items in Cart in Prior set.png')
# Out:
# Most of the people buy 1-15 items in an order and there were a maximum of 145 items in an order.

# %%
print('Percentage of reorder in prior set:',
      format(order_products_prior[order_products_prior.reordered == 1].shape[0]*100/order_products_prior.shape[0], '.2f'))
# Out:
# Percentage of reorder in prior set: 58.97

# %%
fig, ax = plt.subplots(figsize=(3,3))
ax = sns.barplot(x = order_products_prior.reordered.value_counts().index, 
                y = order_products_prior.reordered.value_counts().values, color = color[3])
ax.set_xlabel('Reorder', size = 10)
ax.set_ylabel('Count', size = 10)
ax.tick_params(axis = 'both', labelsize = 8)
ax.ticklabel_format(style='plain', axis='y')
ax.set_title('Reorder Frequency in Prior Set')
fig.savefig('Reorder Frequency in Prior Set')
plt.show()

# %%
# Order Products Train:

# %%
order_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
print("Total: {v1} orders were made where total {v2} products were ordered.".format(v1 = len(order_products_train.order_id.unique()), v2 = len(order_products_train.product_id.unique())))
# Out:
# Total: 131209 orders were made where total 39123 products were ordered.

# %%
add_to_cart_order_train = order_products_prior.groupby('order_id')['add_to_cart_order'].count()
add_to_cart_order_train = add_to_cart_order_train.value_counts()
add_to_cart_order_train.head()
# Out:
# add_to_cart_order
# 5    228330
# 6    227675
# 4    222081
# 7    220006
# 3    207027
# Name: count, dtype: int64

# %%
add_to_cart_order_train.index.max()
# Out:
# 145

# %%
print("Order Products Train \nMost of the people buy 1-15 items in an order and there were a maximum of 145 items in an order.")
fig, ax = plt.subplots(figsize = (15,8))
ax = sns.barplot(x = add_to_cart_order_train.index, y = add_to_cart_order_train.values, color = color[3])
ax.set_xlabel('Items in cart')
ax.set_ylabel('Count')
ax.xaxis.set_tick_params(rotation=90, labelsize = 8)
ax.set_title('Frequency of Items in Cart in Train set', size = 15)
fig.savefig('Frequency of Items in Cart in Train set.png')
# Out:
# Order Products Train
# Most of the people buy 1-15 items in an order and there were a maximum of 145 items in an order.

# %%
print('Percentage of reorder in train set:',
      format(order_products_train[order_products_train.reordered == 1].shape[0]*100/order_products_train.shape[0], '.2f'))
